# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("J:\student-alcohol-consumption.csv" , index_col=0)
df.head(5)
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures schoolsup  \
# 0     GP   F   18     GT3       A     4     4           2         0       yes
# 1     GP   F   17     GT3       T     1     1           1         0        no
# 2     GP   F   15     LE3       T     1     1           1         3       yes
# 3     GP   F   15     GT3       T     4     2           1         0        no
# 4     GP   F   16     GT3       T     3     3           1         0        no
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 29 columns]

# %%
sns.scatterplot(x= "absences" , y = "G3" , data=df , hue ="location")
plt.show()

# %%
sns.scatterplot(x="absences",y="G3" ,data=df,hue="location" , hue_order=["Rural","Urban"])
plt.show()

# %%
# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x="school" , data=df ,hue="location" ,palette = palette_colors)

# Display plot
plt.show()

# %%
sns.relplot(x="absences" , y = "G3", data=df, kind="scatter")
plt.show()

# %%
filt = df["absences"]>70
df[filt]
# Out:
#     school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 276     GP   F   18     GT3       A     3     2           2         0
#
#     schoolsup  ... goout Dalc Walc health absences  G1 G2  G3  location  \
# 276        no  ...     1    1    1      5       75  10  9   9     Rural
#
#        study_time
# 276  2 to 5 hours
#
# [1 rows x 29 columns]

# %%
sns.relplot(x="absences" , y = "G3", data=df, kind="scatter" , col="study_time")
plt.show()

# %%
sns.relplot(x="absences" , y = "G3", data=df, kind="scatter" , row="study_time")
plt.show()

# %%
sns.relplot(x="G1",y="G3",data=df , kind="scatter")
plt.show()

# %%
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3", 
            data=df,
            kind="scatter", 
            row="study_time")

# Show plot
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=df,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])

# Show plot
plt.show()
