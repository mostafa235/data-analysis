# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("J:/Data science/ML/Pyhon for ML/3.1 UNZIP_ME_FOR_NOTEBOOKS_V4/DATA/dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df.describe()
# Out:
#        training level  work experience         salary          sales
# count     1000.000000       1000.00000    1000.000000    1000.000000
# mean         1.262000          6.14200   90264.207000  339833.846000
# std          0.925317          2.94797   17398.617174  108555.773316
# min          0.000000          0.00000   41660.000000   53067.000000
# 25%          1.000000          4.00000   77584.000000  259257.500000
# 50%          1.000000          6.00000   89946.000000  338145.500000
# 75%          2.000000          8.00000  101834.250000  415210.250000
# max          3.000000         16.00000  159148.000000  761477.000000

# %%
sns.scatterplot(data=df,x='salary', y = 'sales');

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(data =df, x = 'salary' , y='sales');

# %%
plt.figure(figsize=(7,3),dpi=100)
sns.scatterplot(data =df, x= 'salary', y='sales' , hue='division');

# %%
plt.figure(figsize=(7,3),dpi=100)
sns.scatterplot(data =df, x= 'salary', y='sales' , hue='level of education');

# %%
df['work experience'].unique()
# Out:
# array([ 6, 10,  9,  5,  2,  3,  4,  7,  0,  8, 11,  1, 13, 12, 14, 16, 15],
#       dtype=int64)

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , hue='work experience');

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , hue='work experience' , palette='viridis');

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , size="work experience");

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , s=77);

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , linewidth=1 ,alpha=.4);

# %%
plt.figure(figsize=(7,3),dpi=150)
sns.scatterplot(data =df, x= 'salary', y='sales' , style='level of education' ,hue='level of education' );
