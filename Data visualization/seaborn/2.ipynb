# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mpg = pd.read_csv("J:\mpg.csv" , index_col=0)
mpg.head(5)
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model_year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
#
#      origin                       name
# mpg
# 18.0    usa  chevrolet chevelle malibu
# 15.0    usa          buick skylark 320
# 18.0    usa         plymouth satellite
# 16.0    usa              amc rebel sst
# 17.0    usa                ford torino

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders")

# Show plot
plt.show()

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", data=mpg, kind="scatter", size="cylinders" , hue="cylinders")

# Show plot
plt.show()

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of acceleration vs. mpg
sns.relplot(x="acceleration", y="mpg", data=mpg, kind="scatter", size="origin" , hue="origin",
            hue_order=["japan","usa","europe"],
            style="origin")

# Show plot
plt.show()

# %%
sns.relplot(x="model_year", y="mpg", data=mpg , kind="line")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABDELR~1\AppData\Local\Temp/ipykernel_11144/3291990424.py in <module>
# ----> 1 sns.relplot(x="model_year", y="mpg", data=mpg , kind="line")
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1034
#    1035     # Draw the plot
# -> 1036     g.map_dataframe(func, **plot_kws)
#    1037
# ...

# %%
# Change to create subgroups for country of origin
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABDELR~1\AppData\Local\Temp/ipykernel_11144/2773248748.py in <module>
#       1 # Change to create subgroups for country of origin
# ----> 2 sns.relplot(x="model_year", y="horsepower",
#       3             data=mpg, kind="line",
#       4             ci=None)
#       5
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
# ...
