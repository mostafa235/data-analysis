# %%
import pandas as pd

# %%
data = [[10, 'male', 57.5],
       [40, 'male', 60],
       [70, 'male', 45],
       [10, 'female', 55]]

# %%
data
# Out:
# [[10, 'male', 57.5], [40, 'male', 60], [70, 'male', 45], [10, 'female', 55]]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     0       1     2
# 0  10    male  57.5
# 1  40    male  60.0
# 2  70    male  45.0
# 3  10  female  55.0

# %%
myindex = ['abdo' , 'ahmed' , 'mohmaed' , 'asmaa']
mycol = ['age','gender' , 'degree']

# %%
df = pd.DataFrame(data = data, index=myindex , columns = mycol )
df
# Out:
#          age  gender  degree
# abdo      10    male    57.5
# ahmed     40    male    60.0
# mohmaed   70    male    45.0
# asmaa     10  female    55.0

# %%
df = pd.read_csv('E:/data/Ebook.csv')
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree           NaN
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male            NaN                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree           NaN
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df.tail()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 43    male        group B                some college  free/reduced
# 44  female           none          associate's degree  free/reduced
# 45    male        group B          associate's degree      standard
# 46  female        group A          associate's degree      standard
# 47  female        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 43               completed        59.0           65.0           66.0
# 44                    none        50.0           56.0           54.0
# 45                    none        65.0           54.0           57.0
# 46               completed        55.0           65.0           62.0
# 47                    none        66.0           71.0           76.0

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       48 non-null     object
#  1   race/ethnicity               45 non-null     object
#  2   parental level of education  48 non-null     object
#  3   lunch                        47 non-null     object
#  4   test preparation course      43 non-null     object
#  5   math score                   45 non-null     float64
#  6   reading score                44 non-null     float64
#  7   writing score                47 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 3.1+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count   45.000000      44.000000      47.000000
# mean    63.777778      67.863636      65.489362
# std     14.901020      14.317969      14.710056
# min     18.000000      32.000000      28.000000
# 25%     55.000000      56.750000      56.000000
# 50%     65.000000      70.000000      66.000000
# 75%     72.000000      75.000000      75.000000
# max     97.000000      95.000000      93.000000

# %%
df.shape
# Out:
# (48, 8)

# %%
len(df)
# Out:
# 48
