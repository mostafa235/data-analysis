# %%
import pandas as pd

# %%
df = pd.read_csv('E:/data/Ebook.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree           NaN
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df['math score'] > 75
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: math score, dtype: bool

# %%
(df['math score'] > 75) & (df['writing score'] > 90)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
filt = df['math score'] > 75
df[filt]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male            NaN                some college      standard
# 6   female        group B                some college      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 34    male        group E                some college      standard
# 35    male      asfafcacv          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 4                     none        76.0           78.0           75.0
# 6                completed        88.0           95.0           92.0
# 13               completed        78.0           72.0           70.0
# 16                    none        88.0           89.0            NaN
# 18               completed        90.0           42.0           46.0
# ...

# %%
filt = df['math score'] > 75
df.loc[filt , 'math score']
# Out:
# 4     76.0
# 6     88.0
# 13    78.0
# 16    88.0
# 18    90.0
# 34    97.0
# 35    81.0
# Name: math score, dtype: float64

# %%
df[df['math score'] > 75]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male            NaN                some college      standard
# 6   female        group B                some college      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 34    male        group E                some college      standard
# 35    male      asfafcacv          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 4                     none        76.0           78.0           75.0
# 6                completed        88.0           95.0           92.0
# 13               completed        78.0           72.0           70.0
# 16                    none        88.0           89.0            NaN
# 18               completed        90.0           42.0           46.0
# ...

# %%
df[(df['math score']>75) & (df['gender']== 'male')]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 4    male            NaN                some college      standard
# 13   male        group A                some college      standard
# 16   male        group C                 high school      standard
# 18   male        group C             master's degree  free/reduced
# 34   male        group E                some college      standard
# 35   male      asfafcacv          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 4                     none        76.0           78.0           75.0
# 13               completed        78.0           72.0           70.0
# 16                    none        88.0           89.0            NaN
# 18               completed        90.0           42.0           46.0
# 34                    none        97.0           87.0           82.0
# 35               completed        81.0           81.0           79.0

# %%
groups = ['group A','group D']
df['race/ethnicity'].isin(groups)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25     True
# 26    False
# 27    False
# 28    False
# 29     True
# 30     True
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46     True
# 47    False
# Name: race/ethnicity, dtype: bool

# %%
df[df['race/ethnicity'].isin(['group A','group D'])]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 8     male        group D                 high school  free/reduced
# 11    male        group D          associate's degree      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 29  female        group D             master's degree      standard
# 30  female        group D                some college      standard
# 33    male        group D                some college      standard
# 38  female        group D          associate's degree  free/reduced
# 46  female        group A          associate's degree      standard
#
# ...
