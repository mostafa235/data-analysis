# %%
import pandas as pd

# %%
df = pd.read_csv('E:/data/Ebook.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree           NaN
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df[['gender','lunch','math score']].head()
# Out:
#    gender         lunch  math score
# 0  female      standard        72.0
# 1  female      standard        69.0
# 2  female           NaN         NaN
# 3    male  free/reduced         NaN
# 4    male      standard        76.0

# %%
df['new_col'] = df['math score'] + df['reading score']

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree           NaN
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score  new_col
# 0                    none        72.0           72.0           74.0    144.0
# 1               completed        69.0           90.0           88.0    159.0
# 2                    none         NaN           95.0           93.0      NaN
# 3                    none         NaN           57.0           44.0      NaN
# 4                    none        76.0           78.0           75.0    154.0

# %%
df = df.drop('new_col',axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree           NaN
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df = df.set_index('gender')
df.head()
# Out:
#         index race/ethnicity parental level of education         lunch  \
# gender
# female      0        group B           bachelor's degree      standard
# female      1        group C                some college      standard
# female      2        group B             master's degree           NaN
# male        3       ssssssss          associate's degree  free/reduced
# male        4            NaN                some college      standard
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none        72.0           72.0           74.0
# female               completed        69.0           90.0           88.0
# female                    none         NaN           95.0           93.0
# male                      none         NaN           57.0           44.0
# male                      none        76.0           78.0           75.0

# %%
df = df.reset_index()
df.head()
# Out:
#    gender  index race/ethnicity parental level of education         lunch  \
# 0  female      0        group B           bachelor's degree      standard
# 1  female      1        group C                some college      standard
# 2  female      2        group B             master's degree           NaN
# 3    male      3       ssssssss          associate's degree  free/reduced
# 4    male      4            NaN                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df.iloc[4]
# Out:
# gender                                 male
# index                                     4
# race/ethnicity                          NaN
# parental level of education    some college
# lunch                              standard
# test preparation course                none
# math score                             76.0
# reading score                          78.0
# writing score                          75.0
# Name: 4, dtype: object

# %%
df.iloc[7:15]
# Out:
#     gender  index race/ethnicity parental level of education         lunch  \
# 7     male      7        group B                some college  free/reduced
# 8     male      8        group D                 high school  free/reduced
# 9   female      9        group B                 high school  free/reduced
# 10    male     10        group C          associate's degree      standard
# 11    male     11        group D          associate's degree      standard
# 12  female     12        group B                 high school      standard
# 13    male     13        group A                some college      standard
# 14  female     14        group A             master's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 7                     none         NaN            NaN           39.0
# 8                completed        64.0           64.0           67.0
# 9                     none        38.0            NaN           50.0
# ...

# %%
df.iloc[[0,1,2,25]]
# Out:
#     gender  index race/ethnicity parental level of education         lunch  \
# 0   female      0        group B           bachelor's degree      standard
# 1   female      1        group C                some college      standard
# 2   female      2        group B             master's degree           NaN
# 25    male     25        group A             master's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none        72.0           72.0           74.0
# 1                completed        69.0           90.0           88.0
# 2                     none         NaN           95.0           93.0
# 25                    none        73.0           74.0           72.0

# %%
df = df.set_index('race/ethnicity')
df.head()
# Out:
#                 gender  index parental level of education         lunch  \
# race/ethnicity
# group B         female      0           bachelor's degree      standard
# group C         female      1                some college      standard
# group B         female      2             master's degree           NaN
# ssssssss          male      3          associate's degree  free/reduced
# NaN               male      4                some college      standard
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group B                           none        72.0           72.0
# group C                      completed        69.0           90.0
# group B                           none         NaN           95.0
# ssssssss                          none         NaN           57.0
# NaN                               none        76.0           78.0
#
#                 writing score
# race/ethnicity
# group B                  74.0
# ...

# %%
df.loc['group B'].head()
# Out:
#                 gender  index parental level of education         lunch  \
# race/ethnicity
# group B         female      0           bachelor's degree      standard
# group B         female      2             master's degree           NaN
# group B         female      5          associate's degree      standard
# group B         female      6                some college      standard
# group B           male      7                some college  free/reduced
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group B                           none        72.0           72.0
# group B                           none         NaN           95.0
# group B                            NaN        71.0           83.0
# group B                      completed        88.0           95.0
# group B                           none         NaN            NaN
#
#                 writing score
# race/ethnicity
# group B                  74.0
# ...

# %%
df.loc[['group B','group C']]
# Out:
#                 gender  index parental level of education         lunch  \
# race/ethnicity
# group B         female      0           bachelor's degree      standard
# group B         female      2             master's degree           NaN
# group B         female      5          associate's degree      standard
# group B         female      6                some college      standard
# group B           male      7                some college  free/reduced
# group B         female      9                 high school  free/reduced
# group B         female     12                 high school      standard
# group B         female     17            some high school  free/reduced
# group B         female     21                some college  free/reduced
# group B           male     26                some college      standard
# group B         female     31                some college      standard
# group B           male     39          associate's degree  free/reduced
# ...

# %%
df = df.reset_index()
df.head()
# Out:
#   race/ethnicity  gender  index parental level of education         lunch  \
# 0        group B  female      0           bachelor's degree      standard
# 1        group C  female      1                some college      standard
# 2        group B  female      2             master's degree           NaN
# 3       ssssssss    male      3          associate's degree  free/reduced
# 4            NaN    male      4                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none         NaN           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0
