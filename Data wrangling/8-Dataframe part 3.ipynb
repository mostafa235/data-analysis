# %%
import pandas as pd

# %%
df = pd.read_csv('E:/data/Ebook.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0             74
# 1               completed        69.0           90.0             88
# 2                    none         NaN           95.0             93
# 3                    none        55.0           57.0             44
# 4                    none         NaN            NaN             75

# %%
df.sort_values("math score", ascending=True)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 17  female        group B            some high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 11    male        group D          associate's degree      standard
# 33    male        group D                some college      standard
# 22    male        group D                some college      standard
# 44  female           none          associate's degree  free/reduced
# 37  female            NaN            some high school  free/reduced
# 42  female        group B          associate's degree      standard
# 19  female        group C          associate's degree  free/reduced
# 40    male        group C          associate's degree  free/reduced
# 3     male       ssssssss          associate's degree  free/reduced
# 46  female        group A          associate's degree      standard
# 32  female        group E             master's degree  free/reduced
# ...

# %%
df.sort_values(["math score" , "reading score"])
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 17  female        group B            some high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 33    male        group D                some college      standard
# 11    male        group D          associate's degree      standard
# 22    male        group D                some college      standard
# 44  female           none          associate's degree  free/reduced
# 37  female            NaN            some high school  free/reduced
# 42  female        group B          associate's degree      standard
# 19  female        group C          associate's degree  free/reduced
# 3     male       ssssssss          associate's degree  free/reduced
# 40    male        group C          associate's degree  free/reduced
# 46  female        group A          associate's degree      standard
# 32  female        group E             master's degree  free/reduced
# ...

# %%
df.iloc[5]
# Out:
# gender                          female
# race/ethnicity                 group B
# parental level of education        NaN
# lunch                              NaN
# test preparation course            NaN
# math score                         NaN
# reading score                      NaN
# writing score                       55
# Name: 5, dtype: object

# %%
df['math score'].max()
# Out:
# 97.0

# %%
df['math score'].idxmax()
# Out:
# 34

# %%
df['math score'].idxmin()
# Out:
# 17

# %%
df['math score'].min()
# Out:
# 18.0

# %%
df['gender'].value_counts()
# Out:
# female    26
# male      22
# Name: gender, dtype: int64

# %%
df['gender'] = df['gender'].astype(str)

# %%
df['gender'].dtype
# Out:
# dtype('O')

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'ssssssss', 'group D', 'group A', 'group E',
#        'asfafcacv', nan, 'none'], dtype=object)

# %%
df['race/ethnicity'].nunique()
# Out:
# 8

# %%
df['math score'].between(70,80,inclusive=True)
# Out:
# C:\Users\ABDELR~1\AppData\Local\Temp/ipykernel_21016/3934524705.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df['math score'].between(70,80,inclusive=True)
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: math score, dtype: bool

# %%
df[df['math score'].between(70,80,inclusive = True)]
# Out:
# C:\Users\ABDELR~1\AppData\Local\Temp/ipykernel_21016/2936955713.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df[df['math score'].between(70,80,inclusive = True)]
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 13    male        group A                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 28    male        group C                 high school      standard
# 36  female            NaN          associate's degree      standard
# 38  female        group D          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none        72.0           72.0             74
# ...

# %%
df['math score'].nlargest(10)
# Out:
# 34    97.0
# 18    90.0
# 6     88.0
# 35    81.0
# 13    78.0
# 38    75.0
# 24    74.0
# 36    74.0
# 25    73.0
# 0     72.0
# Name: math score, dtype: float64

# %%
df['math score'].nsmallest(10)
# Out:
# 17    18.0
# 9     38.0
# 11    40.0
# 33    40.0
# 22    44.0
# 37    50.0
# 44    50.0
# 42    53.0
# 19    54.0
# 3     55.0
# Name: math score, dtype: float64

# %%
df.nlargest(10,'math score')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 34    male        group E                some college      standard
# 18    male        group C             master's degree  free/reduced
# 6   female        group B                some college      standard
# 35    male      asfafcacv          associate's degree      standard
# 13    male        group A                some college      standard
# 38  female        group D          associate's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
# 36  female            NaN          associate's degree      standard
# 25    male        group A             master's degree  free/reduced
# 0   female        group B           bachelor's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 34                    none        97.0           87.0             82
# 18               completed        90.0           42.0             50
# ...

# %%
df.nsmallest(10,'math score')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 17  female        group B            some high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 11    male        group D          associate's degree      standard
# 33    male        group D                some college      standard
# 22    male        group D                some college      standard
# 37  female            NaN            some high school  free/reduced
# 44  female           none          associate's degree  free/reduced
# 42  female        group B          associate's degree      standard
# 19  female        group C          associate's degree  free/reduced
# 3     male       ssssssss          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 17                    none        18.0           32.0             28
# 9                     none        38.0            NaN             50
# ...
