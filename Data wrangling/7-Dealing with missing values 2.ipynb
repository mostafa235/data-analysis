# %%
import pandas as pd

# %%
df = pd.read_csv('E:/data/Ebook.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male       ssssssss          associate's degree  free/reduced
# 4    male        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0             74
# 1               completed        69.0           90.0             88
# 2                    none         NaN           95.0             93
# 3                    none        55.0           57.0             44
# 4                    none         NaN            NaN             75

# %%
df.fillna("missing")
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                     missing       missing
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.fillna(0)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                           0             0
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df['math score'].fillna(0)
# Out:
# 0     72.0
# 1     69.0
# 2      0.0
# 3     55.0
# 4      0.0
# 5      0.0
# 6     88.0
# 7      0.0
# 8     64.0
# 9     38.0
# 10     0.0
# 11    40.0
# 12    65.0
# 13    78.0
# 14     0.0
# 15    69.0
# 16     0.0
# 17    18.0
# 18    90.0
# 19    54.0
# 20    66.0
# 21    65.0
# 22    44.0
# 23    69.0
# 24    74.0
# 25    73.0
# 26    69.0
# 27    67.0
# 28    70.0
# 29    62.0
# 30    69.0
# 31    63.0
# 32    56.0
# 33    40.0
# 34    97.0
# 35    81.0
# 36    74.0
# 37    50.0
# 38    75.0
# 39    57.0
# 40    55.0
# 41    58.0
# 42    53.0
# 43    59.0
# 44    50.0
# 45    65.0
# 46    55.0
# 47    66.0
# Name: math score, dtype: float64

# %%
df['lunch'] = df['lunch'].fillna("empty")

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                         NaN         empty
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df['math score'].mean()
# Out:
# 62.97560975609756

# %%
df['math score'].fillna(df['math score'].mean())
# Out:
# 0     72.00000
# 1     69.00000
# 2     62.97561
# 3     55.00000
# 4     62.97561
# 5     62.97561
# 6     88.00000
# 7     62.97561
# 8     64.00000
# 9     38.00000
# 10    62.97561
# 11    40.00000
# 12    65.00000
# 13    78.00000
# 14    62.97561
# 15    69.00000
# 16    62.97561
# 17    18.00000
# 18    90.00000
# 19    54.00000
# 20    66.00000
# 21    65.00000
# 22    44.00000
# 23    69.00000
# 24    74.00000
# 25    73.00000
# 26    69.00000
# 27    67.00000
# 28    70.00000
# 29    62.00000
# 30    69.00000
# 31    63.00000
# 32    56.00000
# 33    40.00000
# 34    97.00000
# 35    81.00000
# 36    74.00000
# 37    50.00000
# 38    75.00000
# 39    57.00000
# 40    55.00000
# 41    58.00000
# 42    53.00000
# 43    59.00000
# 44    50.00000
# 45    65.00000
# 46    55.00000
# 47    66.00000
# Name: math score, dtype: float64

# %%
df.fillna(df.mean())
# Out:
# C:\Users\ABDELR~1\AppData\Local\Temp/ipykernel_14468/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                         NaN         empty
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# ...

# %%
df['math score'].interpolate()
# Out:
# 0     72.0
# 1     69.0
# 2     62.0
# 3     55.0
# 4     66.0
# 5     77.0
# 6     88.0
# 7     76.0
# 8     64.0
# 9     38.0
# 10    39.0
# 11    40.0
# 12    65.0
# 13    78.0
# 14    73.5
# 15    69.0
# 16    43.5
# 17    18.0
# 18    90.0
# 19    54.0
# 20    66.0
# 21    65.0
# 22    44.0
# 23    69.0
# 24    74.0
# 25    73.0
# 26    69.0
# 27    67.0
# 28    70.0
# 29    62.0
# 30    69.0
# 31    63.0
# 32    56.0
# 33    40.0
# 34    97.0
# 35    81.0
# 36    74.0
# 37    50.0
# 38    75.0
# 39    57.0
# 40    55.0
# 41    58.0
# 42    53.0
# 43    59.0
# 44    50.0
# 45    65.0
# 46    55.0
# 47    66.0
# Name: math score, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                some college         empty
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.fillna(method='bfill')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male       ssssssss          associate's degree  free/reduced
# 4     male        group B                some college      standard
# 5   female        group B                some college         empty
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...
